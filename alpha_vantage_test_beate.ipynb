# %% [markdown]
# ## Test of Alpha vantage API
# https://www.alphavantage.co/documentation/
# https://github.com/RomelTorres/alpha_vantage/blob/develop/README.md
# You should be able to install by using the direct download from git and then pip install....
# as it says in the examples of readme as well...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
from alpha_vantage.timeseries import TimeSeries
ts = TimeSeries(key='MAINUT5068DCQGJ9',output_format='pandas')
# Get json object with the intraday data and another with  the call's metadata



# get all available daily data (Netflix)
data, meta_data = ts.get_daily('NFLX',outputsize='full')

# %%
data.head()
data['4. close'].plot()
